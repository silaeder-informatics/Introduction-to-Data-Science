# %%
from random import randint
X = [[i] for i in range(100)]
Y = [3 * x + 30 + randint(-30, 30) for x in X]

# %%
X = [[x] for x in X]

# %%
import csv

X = []
Y = []
apnd = []
with open('Boston_Housing.csv', newline='') as csvfile:
    text = csv.reader(csvfile, delimiter=',')
    for row in text:
        if row[0] != 'crim':
            for i in range(len(row)):
                if i != len(row) - 1:
                    row[i] = float(row[i])
                else:
                    Y.append(float(row[i]))
                
            X.append(row[0 : len(row) - 1])

# print(Y)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, Y)

k = model.coef_
b = model.intercept_

print(f'k = {k}')
print(f'b = {b}')

Y_predicted = model.predict(X)
# Out:
# k = [-1.08011358e-01  4.64204584e-02  2.05586264e-02  2.68673382e+00
#  -1.77666112e+01  3.80986521e+00  6.92224640e-04 -1.47556685e+00
#   3.06049479e-01 -1.23345939e-02 -9.52747232e-01  9.31168327e-03
#  -5.24758378e-01]
# b = 36.459488385090125

# %%
import matplotlib.pyplot as plt

plt.plot(X, Y, 'o')
plt.plot(X, Y_predicted)
# Out:
# [<matplotlib.lines.Line2D at 0x7f71d170c820>,
#  <matplotlib.lines.Line2D at 0x7f7192662cd0>,
#  <matplotlib.lines.Line2D at 0x7f7192662d90>,
#  <matplotlib.lines.Line2D at 0x7f7192662e50>,
#  <matplotlib.lines.Line2D at 0x7f7192662f10>,
#  <matplotlib.lines.Line2D at 0x7f7192662fd0>,
#  <matplotlib.lines.Line2D at 0x7f719266f0d0>,
#  <matplotlib.lines.Line2D at 0x7f719266f190>,
#  <matplotlib.lines.Line2D at 0x7f719266f250>,
#  <matplotlib.lines.Line2D at 0x7f719266f310>,
#  <matplotlib.lines.Line2D at 0x7f719266f3d0>,
#  <matplotlib.lines.Line2D at 0x7f719266f490>,
#  <matplotlib.lines.Line2D at 0x7f719266f550>]

# %%
import math

dist = [((Y[i] - Y_predicted[i]) / Y[i]) ** 2 for i in range(len(Y_predicted))]
print(math.sqrt(sum(dist) / len(dist)))
# Out:
# 0.24758895690520535

# %%
from sklearn.metrics import mean_squared_error

print(mean_squared_error(Y, Y_predicted) ** 0.5)
# Out:
# 4.679191295697281

# %%
Y_ans = model.predict([[0.00632, 18, 2.31, 0, 0.538, 6.575, 65.2, 4.09, 1, 296, 15.3, 396, 4.98]])
Y_ans
# Out:
# array([29.99546286])
