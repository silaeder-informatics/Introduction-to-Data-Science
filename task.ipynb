# %%
import numpy as np
data = np.array(range(1, 1000))

# %%
data [((data % 3 == 0) | (data % 5 == 0)) & (data % 15 != 0)]
# Out:
# array([  3,   5,   6,   9,  10,  12,  18,  20,  21,  24,  25,  27,  33,
#         35,  36,  39,  40,  42,  48,  50,  51,  54,  55,  57,  63,  65,
#         66,  69,  70,  72,  78,  80,  81,  84,  85,  87,  93,  95,  96,
#         99, 100, 102, 108, 110, 111, 114, 115, 117, 123, 125, 126, 129,
#        130, 132, 138, 140, 141, 144, 145, 147, 153, 155, 156, 159, 160,
#        162, 168, 170, 171, 174, 175, 177, 183, 185, 186, 189, 190, 192,
#        198, 200, 201, 204, 205, 207, 213, 215, 216, 219, 220, 222, 228,
#        230, 231, 234, 235, 237, 243, 245, 246, 249, 250, 252, 258, 260,
#        261, 264, 265, 267, 273, 275, 276, 279, 280, 282, 288, 290, 291,
#        294, 295, 297, 303, 305, 306, 309, 310, 312, 318, 320, 321, 324,
#        325, 327, 333, 335, 336, 339, 340, 342, 348, 350, 351, 354, 355,
#        357, 363, 365, 366, 369, 370, 372, 378, 380, 381, 384, 385, 387,
#        393, 395, 396, 399, 400, 402, 408, 410, 411, 414, 415, 417, 423,
# ...
