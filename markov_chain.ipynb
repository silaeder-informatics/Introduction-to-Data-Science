# %%
import random
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()

# %%
file = open("Detstvo.txt","r",encoding="utf8")
InputText = file.read()
# InputText = ""
PuncMarks = "!@#$%^&*()-+=_\"\',./\\№;:\n"

# %%
def preprocess(text):
    for mark in PuncMarks:
        text = text.replace(mark, " ")
    return text.lower()

# %%
TextToChain = f"{preprocess(InputText)}"

# %%
vectorizer = CountVectorizer(ngram_range=(2,2), stop_words=[])
vectorizer.fit([TextToChain])
pairs = [f"*START* {TextToChain.split()[0]}"] + vectorizer.get_feature_names() + [f"{TextToChain.split()[-1]} *END*"]

# %%
chainsRaw = [pair.split() for pair in pairs]

# %%
chains = {}
for chainRaw in chainsRaw:
    if chainRaw[0] in chains:
        if not chainRaw[1] in chains[chainRaw[0]]:
            chains[chainRaw[0]].append(chainRaw[1])
    else:
        chains[chainRaw[0]] = []
        chains[chainRaw[0]].append(chainRaw[1])

# %%
text = ""
currentWord = "*START*"
while True:
    currentWord = chains[currentWord][random.randint(0, len(chains[currentWord]) - 1)]
    if currentWord == "*END*":
        text = text[:-1]
        break
    text += currentWord + " "
text
# Out:
# 'горький детство горький максим уж как деревянные стояли какие законы это хуже испугались все уставились на крючок окуни голавли лещи вот пить водку особенно интересно всё черти потом идут построенные из концов то вбок давно забытое она шла тихонько спокойненько упрямо слушай всех делах он грозил ложкой али трудно богатого мужа украсть одного цвета расхлебянила дверь призывая варя тоже что поёт светлы ангелы веселятся плещут крыльями поют хорошо это охапками комнаты встал на бегу зарывался головою лицо её портило обижало вдруг начинал поучать мы квартального кое что мало осторожно словно бесшумно притопывая такт молитве всё было мне мне пел бы нас четверых взятых вместе птицами прямо лицо неё крепко он грозил ложкой по домам небо черною сетью исчезают куда разные вещи заклад кто этот ласковый её этот ласковый её видны освещённые фонарями ворота она молилась недолго проживёте ну бей его разве бог бессонницу ух ты то на друга до холеры год только приказывала сходи евгению васильевичу скажи ему ведь как очутился комнате матери раскладывал по трактирам ходят ноют хлеба гуще привозил мне школа вызвала во всём догадался приглядывал за чужую совесть дёргает его задавили глухо мычавших детей падали вовремя сказать их уж старая лошадь всё горячей суетливостью зелёные глаза рукою стену набиты наличники них деньги то запирать остались со всей полной густым голосом дверь села окна стало матушке всяко вралём когда вошёл остановился трогает за нос глаза ней разорвалось волосы тяжёлой руки за стулом дети лучше всех чаем за углов губ борисоглебского уезда слышал его голоса речи успокаивали его согнувшись над волгой солнце очень удивляло меня сильнее тебя тут уж черти всем он напряжённо слежу не увидали его мою болтовню внимательно выслушал горести мои рученьки больно тут обомлела язык сердилась кричала она могла обольститься человеком это трепал ей самой больно сердце вдруг он улыбался всегда они обе рамы явилась бабушка мокрый бледен до ночи ой скушно очень ясные но светилась изнутри распирает грудь закинув голову подошел ней сшиб ее вздыхая экой ведь когда выздоровел мне страх не возникало желания скрывать однажды заснул вдруг выскочил на седалище покрытое мною птицы щебетали весёлые песни не бухал дрожал обиженно надул ишь ты живи де дедушка всегда серьёзно разговаривая васильем он возбуждался дрожали очки помахивал ими мачехе отце моем клюшникове бойце из души ни положь всё вытирал быстрым движением руки поднять ни жив ни мать разглядывая обрезки листы принесу пошёл вприсядку кругом нет пошла мы назад кричали друг другом не решался никогда не отняла его небо лицо зажигая тёмные люди пошёл святой молитве всё поскорости после отъезда хорошего не удались дети были высоко сказал вотчим неустанно радость жили грешили добро попал это легче подмигнув темным косым глазом подмигивая ты об одной крепости чтоб ты ведь живут согласятся вот закрыв глаза щёки ладонью по улице сонная усталость жмёт давит сердце ох грустно да мундир только от всякого смысла но спать немножко можно верно ещё значительней ещё более года уж скоро мы дедом потому что редькин сын родной души меня себе накинув на постель приговаривая испуганно что так мы идя по столам мать не алексей так густо ощетинившийся покрасневшими глазами ощупывая воз всё сильней протянув мне ах лихорадка астраханская чего ты непьющий долго присматривается ним уймись строго непонятно максимов терпеливо поправляла голосом что пожара любя во дубовый чёлн как ещё что то великом посте заиграл ветер раздувал дым странные слова прикрыв глаза так чтоб вам трусовых большой тебе спасибо сынок мать действительно всё грязное ненужное устроив яме потеряв зрение слух дошёл евгений тоже обращались цыганком ласково простившись со всеми она беседовала ним из лабаза на язык себе тянет лозину чтобы скорее уж на ней незнакомо мне написал святцах эти рассказы не тянула улица оживает смеётся колышется вся заплакала спрятав голову яме где она подолгу жил уже смотрело солнце очень учиться мы идя по привычке для шутки опять др ...

# %%
vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(2, 2), preprocessor=None, stop_words=[],
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)
