# %%
import pandas as pd

data = pd.read_csv('mos_ru_news_save.csv')
data.head()
# Out:
#         Date                                               News  \
# 0  18 апреля  Зафиксированы новые случаи заражения коронавир...
# 1  18 апреля  В столице от коронавируса вылечились уже 1679 ...
# 2  18 апреля  Цирк на проспекте Вернадского присоединился к ...
# 3  18 апреля  Лекции и виртуальные экскурсии: как пройдет он...
# 4  17 апреля  Большинство умерших от коронавируса имели сопу...
#
#              Class                                     Link  \
# 0  Здравоохранение  https://www.mos.ru//news/item/72823073/
# 1  Здравоохранение  https://www.mos.ru//news/item/72822073/
# 2  Культура онлайн  https://www.mos.ru//news/item/72786073/
# 3         Культура  https://www.mos.ru//news/item/72815073/
# 4  Здравоохранение  https://www.mos.ru//news/item/72818073/
#
#                                                 Text  \
# 0  Фото: Пресс-служба Мэра и Правительства Москвы...
# 1  Фото: Пресс-служба Мэра и Правительства Москвы...
# ...

# %%
def check(string):
    return 'Коронавирус' in string

# %%
data[data['Text'].apply(check)]
# Out:
#           Date                                               News  \
# 0    18 апреля  Зафиксированы новые случаи заражения коронавир...
# 1    18 апреля  В столице от коронавируса вылечились уже 1679 ...
# 15   17 апреля  Восемь трансформаторных подстанций установят д...
# 16   17 апреля  Вице-мэр Анастасия Ракова поблагодарила столич...
# 26   16 апреля  Всем пациентам с ОРВИ врачи будут уделять повы...
# ..         ...                                                ...
# 592   18 марта  В Москве зафиксированы новые случаи заболевани...
# 593   18 марта  Правительство России утвердило правила оформле...
# 597   18 марта  106 пациентов выписаны из больницы в Коммунарк...
# 603   18 марта  Ленинка, зоопарк и Третьяковская галерея: каки...
# 604   18 марта  Борьба с коронавирусом: скорая помощь работает...
#
#                    Class                                     Link  \
# 0        Здравоохранение  https://www.mos.ru//news/item/72823073/
# ...

# %%
len(data['Date'])
# Out:
# 612
