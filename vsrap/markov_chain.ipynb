# %%
import random
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()

# %%
file = open("oxxxymiron.txt", "r", encoding="utf8")
InputText = file.read()
# InputText = ""
PuncMarks = "!@#$%^&*()-+=_\"\',./\\№;:\n"

# %%
def preprocess(text):
    for mark in PuncMarks:
        text = text.replace(mark, " ")
    return text.lower()

# %%
TextToChain = f"{preprocess(InputText)}"

# %%
vectorizer = CountVectorizer(ngram_range=(2,2), stop_words=[])
vectorizer.fit([TextToChain])
pairs = [f"*START* {TextToChain.split()[0]}"] + vectorizer.get_feature_names() + [f"{TextToChain.split()[-1]} *END*"]

# %%
chainsRaw = [pair.split() for pair in pairs]

# %%
chains = {}
for chainRaw in chainsRaw:
    if chainRaw[0] in chains:
        if not chainRaw[1] in chains[chainRaw[0]]:
            chains[chainRaw[0]].append(chainRaw[1])
    else:
        chains[chainRaw[0]] = []
        chains[chainRaw[0]].append(chainRaw[1])

# %%
text = ""
currentWord = "*START*"
while True:
    currentWord = chains[currentWord][random.randint(0, len(chains[currentWord]) - 1)]
    if currentWord == "*END*":
        text = text[:-1]
        break
    text += currentWord + " "
text
# Out:
# 'здесь ты дитя бетонной коробки лифтом где каждый из коллектива вы бездари все знали английский на нервы детский сад взрослеть пора про меня искра буря безумие год еще год по полной хуете куплеты поверх октав наверняка закрепи как надо хватит корчиться креативить твой трек среди mp3 шек гулял это масонское ложе осознанна ложь тотальная слежка нехуёвое блядь снусмумрики хатифнаты индабаттла копирки под хлороформом на город устаёт чинить за пытайся сам это скелеты тех что процитирую свои знаешь пока тут правда народ рэп ебучая хуйня послушай совет пока кто любит красть просто трактир семья обик драго друзья мы взлетим среди mp3 шек шек послушай совет пока город устаёт чинить за оскорбления навалял потом был вдруг появляется серёга черный бумер king of little italy кто ещё цветочки мы живём так вам не индиана но тут своим блядям звонить при содействии икон твой хайп это время уходить гуляй поле гонит неба ветерок всё назад бумерангом не авторитет вы думаете это кал стайл ребята это лишь маленький пидор ну кем тебя под алко ты теряешь если не изобретёнными твоя карьера здоровье курорт то русский язык на левом плече гамаюн на ладони под гору когда каждый из англии выйти всех разные вкусы кому то кричащий так хотел мой но лицом того за мелочь от печати до вожделенной щели сука это заговор проект поменявший весь мой орган аортой всё предельно серьёзно она банчит шикарной одеждою за нитки каково жить глубже дышать девочка пиздец новатор вот рискуете увидеть ты бегал заведомо делал свой текст фейк мол нас принято эй дошли не тест рэп признали мне обещает страдание но мне думалось попал горгород пойми гибрид сухощавой свиньи китайца крип болен этим ни черта за хайпа не макиавелли никколо благоговеет влекомо плахе петле или для торжеств fuck that можно не сопротивляйся дитя бетонной коробки лифтом где чейни на ритм срать но твоих родаков не следствие тут себе туз подготовься аркхем предоставляет ночлег откуда тебя нашел серёга первым тебя хватит сравнивать нас по фану поглумиться над крышами везде мое ученье всем похуй не он поэт ты всё нормально ты балагур этом первый раунд это как быстро тоже есть бэтмэна робином него эминем потолок эталон комфортного отдыха гольф аквадром кёрлинг добро пожаловать горгород горгород горгород но мне быть во время цейтнот смерти натюрморт постель чиновника делооборот но кажется дождь где ты графоман сожалению ты таким таким не буду врать воровать байтить ушат дерьма выливать на ура знал нейтралитет рядом какие то здесь пастор поцеловал лазал под ногами учти тебе отдам что oxxxymiron мирон эй беру всё перенести ну ка ram revolt ещё одна там вас здесь бы побыть умней но ни продашь глаза бросается халтурно прорисованный пейзаж лох рэпчик не на поворотах делал прошлый год но тут многие давайте поговорим об меня как часто была искренность баттл шурыгиной дно значит получает извне на углу beckton barking думал текст фейк мол ты готовишь борщи намного лучше других община семья обик драго друзья мы фит после дело личности что еще баттлишь основе versus окей них гандикап кандидат на типичного транса дайте мне почему нету лекарства мало что сдулся но мне объявят единогласный импичмент какого хуя для души не кукарекал boy мне хоть бытовым проявлением негатива двух отдельных людей виден подъём засветло снова дотронешься до дома плакаты со временем изменится может полностью но суть проста во все кеннинг тауна майком на avito мастер маргарита твоего интервью мастер раскрутки ты таким таким не способен пара фраз про слово средь земных тревог евангелии от гардероба говнаря до моей дебетной карте это не кассу от священных коров отвык иалдабаоф он рос на ужин завтрак обед во всю планету став её слова воздух стал полным карман горгород но больно наивный мир пустой ни куплет автопортретом час на тающий апрель май июнь июль ты бежав корабля украл впопыхах дырявую шлюпку набрал команду карланов толкал нам годами клюкву вы дурите всех кем баттлился раньше версус был один мироздание по мамам тот же вам не били ты решил что видит ...
