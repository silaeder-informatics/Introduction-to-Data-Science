# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

filename = 'mos_ru_news.csv'
driver = webdriver.Chrome()
driver.get('https://www.mos.ru/news/')

try:
    for i in range(1):
        element = driver.find_element_by_xpath("//a[@class='mos-button']")
        element.click()
        time.sleep(3)
        print(i)
except Exception as e:
    print(e)
# Out:
# 0

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
data = pd.DataFrame(columns=['Date', 'News', 'Class', 'Link', 'Text', 'Page'])

all_news = soup.find_all('main-news')[0]

# %%
links_to_parse = []

for link in all_news.find_all('a', {'class': 'commonCard__link'}):
    print('https://www.mos.ru/' + link['href'])
    links_to_parse.append('https://www.mos.ru/' + link['href'])
# Out:
# https://www.mos.ru//news/item/72767073/
# https://www.mos.ru//news/item/72702073/
# https://www.mos.ru//news/item/72737073/
# https://www.mos.ru//news/item/72755073/
# https://www.mos.ru//news/item/72577073/
# https://www.mos.ru//news/item/72758073/
# https://www.mos.ru//news/item/72760073/
# https://www.mos.ru//news/item/72752073/
# https://www.mos.ru//news/item/72734073/
# https://www.mos.ru//news/item/72742073/
# https://www.mos.ru//news/item/72732073/
# https://www.mos.ru//news/item/72723073/
# https://www.mos.ru//news/item/72709073/
# https://www.mos.ru//news/item/72708073/
# https://www.mos.ru//news/item/72714073/
# https://www.mos.ru//news/item/72720073/
# https://www.mos.ru//news/item/72719073/
# https://www.mos.ru//news/item/72616073/
# https://www.mos.ru//news/item/72692073/
# https://www.mos.ru//news/item/72691073/
# https://www.mos.ru//news/item/72690073/
# https://www.mos.ru//news/item/72678073/
# https://www.mos.ru//news/item/72701073/
# https://www.mos.ru//news/item/72686073/

# %%
text_arr = []
html_arr = []

for url in links_to_parse:
    driver.get(url)
    time.sleep(2)
    
    text = driver.find_element_by_class_name('news-article-content').text
    
    text_arr.append(text)
    html_arr.append(driver.page_source)
    print(url)
# Out:
# https://www.mos.ru//news/item/72767073/
# https://www.mos.ru//news/item/72702073/
# https://www.mos.ru//news/item/72737073/
# https://www.mos.ru//news/item/72755073/
# https://www.mos.ru//news/item/72577073/
# https://www.mos.ru//news/item/72758073/
# https://www.mos.ru//news/item/72760073/
# https://www.mos.ru//news/item/72752073/
# https://www.mos.ru//news/item/72734073/
# https://www.mos.ru//news/item/72742073/
# https://www.mos.ru//news/item/72732073/
# https://www.mos.ru//news/item/72723073/
# https://www.mos.ru//news/item/72709073/
# https://www.mos.ru//news/item/72708073/
# https://www.mos.ru//news/item/72714073/
# https://www.mos.ru//news/item/72720073/
# https://www.mos.ru//news/item/72719073/
# https://www.mos.ru//news/item/72616073/
# https://www.mos.ru//news/item/72692073/
# https://www.mos.ru//news/item/72691073/
# https://www.mos.ru//news/item/72690073/
# https://www.mos.ru//news/item/72678073/
# https://www.mos.ru//news/item/72701073/
# https://www.mos.ru//news/item/72686073/

# %%
ind = 0

for news in all_news.find_all('div', {'class': 'commonCard'}):
    t = news.findChildren('span', {'class': "commonCard__title"} , recursive=True)
    add = list(news.findChildren('span', {'class': "extraList__item"} , recursive=True))
    
    try:
        data.loc[ind] = {'Date': add[0].text.rstrip('\n'), 'News': t[0].text.rstrip('\n'), 'Class': add[1].text.rstrip('\n'), 'Link': links_to_parse[ind], 'Text': text_arr[ind], 'Page': html_arr[ind]}
    except:
        pass
    
    data.to_csv(filename, index=False)
    ind += 1

data
# Out:
#          Date                                               News  \
# 0       09:24  Арендаторы городского имущества смогут получит...
# 1       07:20  Москвичи выбрали концепцию реставрации Дворца ...
# 2       07:18  Все сделки по продаже городской недвижимости с...
# 3       07:10  Игры и развивающие занятия: запущен образовате...
# 4       07:08  Прием заявок на участие в конкурсе «Прорыв год...
# 5       07:00  Быстро оформить цифровой пропуск: в приложении...
# 6   16 апреля  Большинство скончавшихся от коронавируса имели...
# 7   16 апреля  Всем пациентам с ОРВИ врачи будут уделять повы...
# 8   16 апреля  Чернолощеный кувшин и нательные кресты XVI век...
# 9   16 апреля  Застройщики получат отсрочку по арендным платежам
# 10  16 апреля  За стеклом: о работе кассиров в столичной подз...
# 11  16 апреля  На улице Зенитчиков в Митине построят автобусн...
# 12  16 апреля  Стационарные корпуса скорой помощи построят дл...
# 13  16 апреля  Учебный корпус и ФОК построят в Бирюлеве Восто...
# 14  16 апреля  В Марфине ввели в эксплуатацию детскую поликли...
# 15  16 апреля  Все новые заболевшие коронавирусной инфекцией ...
# 16  16 апреля  В Москве от коронавирусной инфекции вылечили п...
# 17  16 апреля  Викторину о столичных электронных проектах зап...
# 18  16 апреля  На портале «Узнай Москву» проведут краеведческ...
# 19  16 апреля  Мосгорнаследие подтвердило ценность ванны в ос...
# 20  16 апреля  #ЧитаемДекамерон: к литературной акции присоед...
# 21  16 апреля    Мосприрода запускает серию экологических тестов
# 22  16 апреля  История Китайгородской стены и Тверской улицы:...
# 23  16 апреля  К 75-летию Победы: юных горожан приглашают поу...
#
#                                    Class  \
# 0        Экономика и предпринимательство
# 1                       Социальная сфера
# 2        Экономика и предпринимательство
# 3                            Образование
# 4        Экономика и предпринимательство
# 5                   Городское управление
# 6                        Здравоохранение
# 7                        Здравоохранение
# 8     Археология и памятники архитектуры
# 9        Экономика и предпринимательство
# 10                             Транспорт
# 11                             Транспорт
# 12         Строительство и реконструкция
# 13  Московская программа реновации жилья
# 14         Строительство и реконструкция
# 15                       Здравоохранение
# 16                       Здравоохранение
# 17                      Социальная сфера
# 18                              Культура
# 19    Археология и памятники архитектуры
# 1   <html lang="ru"><!--<![endif]--><head prefix="...
# 2   <html lang="ru"><!--<![endif]--><head prefix="...
# 3   <html lang="ru"><!--<![endif]--><head prefix="...
# 4   <html lang="ru"><!--<![endif]--><head prefix="...
# 5   <html lang="ru"><!--<![endif]--><head prefix="...
# 6   <html lang="ru"><!--<![endif]--><head prefix="...
# 7   <html lang="ru"><!--<![endif]--><head prefix="...
# 8   <html lang="ru"><!--<![endif]--><head prefix="...
# 9   <html lang="ru"><!--<![endif]--><head prefix="...
# 10  <html lang="ru"><!--<![endif]--><head prefix="...
# 11  <html lang="ru"><!--<![endif]--><head prefix="...
# 12  <html lang="ru"><!--<![endif]--><head prefix="...
# 13  <html lang="ru"><!--<![endif]--><head prefix="...
# 14  <html lang="ru"><!--<![endif]--><head prefix="...
# 15  <html lang="ru"><!--<![endif]--><head prefix="...
# 16  <html lang="ru"><!--<![endif]--><head prefix="...
# 17  <html lang="ru"><!--<![endif]--><head prefix="...
# 18  <html lang="ru"><!--<![endif]--><head prefix="...
# 19  <html lang="ru"><!--<![endif]--><head prefix="...
# 20  <html lang="ru"><!--<![endif]--><head prefix="...
# 21  <html lang="ru"><!--<![endif]--><head prefix="...
# 22  <html lang="ru"><!--<![endif]--><head prefix="...
# 23  <html lang="ru"><!--<![endif]--><head prefix="...

# %%
file = pd.read_csv('mos_ru_news.csv')

file.head()
# Out:
#     Date                                               News  \
# 0  09:24  Арендаторы городского имущества смогут получит...
# 1  07:20  Москвичи выбрали концепцию реставрации Дворца ...
# 2  07:18  Все сделки по продаже городской недвижимости с...
# 3  07:10  Игры и развивающие занятия: запущен образовате...
# 4  07:08  Прием заявок на участие в конкурсе «Прорыв год...
#
#                              Class                                     Link  \
# 0  Экономика и предпринимательство  https://www.mos.ru//news/item/72767073/
# 1                 Социальная сфера  https://www.mos.ru//news/item/72702073/
# 2  Экономика и предпринимательство  https://www.mos.ru//news/item/72737073/
# 3                      Образование  https://www.mos.ru//news/item/72755073/
# 4  Экономика и предпринимательство  https://www.mos.ru//news/item/72577073/
#
#                                                 Text  \
# 0  Фото: mos.ru. Юлия Иванко\nУведомления были ра...
# 1  Проектное решение\nВ голосовании приняли участ...
# 2  Фото: mos.ru. Максим Денисов\nОбщая площадь об...
# 3  Пользователям доступны подборки полезных матер...
# 4  Члены экспертного совета определят победителей...
#
#                                                 Page
# 0  <html lang="ru"><!--<![endif]--><head prefix="...
# 1  <html lang="ru"><!--<![endif]--><head prefix="...
# 2  <html lang="ru"><!--<![endif]--><head prefix="...
# 3  <html lang="ru"><!--<![endif]--><head prefix="...
# 4  <html lang="ru"><!--<![endif]--><head prefix="...
